# %%
import os

repo_url = "https://github.com/FabioFloris02/NLP2026_Floris_Sonzini_Parenti_Sarra_Rossi.git"
repo_name = "NLP2026_Floris_Sonzini_Parenti_Sarra_Rossi"

if os.path.exists(repo_name):
    print("Repository already present, update...")
    # %cd {repo_name}
    # !git pull
else:
    print("Repository clone...")
    # !git clone {repo_url}
    # %cd {repo_name}
# Out:
# Repository already present, update...
# /content/NLP2026_Floris_Sonzini_Parenti_Sarra_Rossi
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 27 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (27/27), 39.38 KiB | 876.00 KiB/s, done.
# From https://github.com/FabioFloris02/NLP2026_Floris_Sonzini_Parenti_Sarra_Rossi
#    ea7c4b0..dce15cb  main       -> origin/main
# Updating ea7c4b0..dce15cb
# Fast-forward
#  NLP_2026.ipynb                                     |  52 +++-
#  NLP_assignment_api_client/PoliMillionaire.ipynb    |   1 +
#  .../millionaire_client/__init__.py                 |  73 +++++
#  .../__pycache__/__init__.cpython-312.pyc           | Bin 0 -> 1708 bytes
#  .../__pycache__/auth.cpython-312.pyc               | Bin 0 -> 2734 bytes
#  .../__pycache__/base.cpython-312.pyc               | Bin 0 -> 8226 bytes
#  .../__pycache__/client.cpython-312.pyc             | Bin 0 -> 5863 bytes
#  .../__pycache__/competitions.cpython-312.pyc       | Bin 0 -> 3202 bytes
#  .../__pycache__/exceptions.cpython-312.pyc         | Bin 0 -> 2674 bytes
#  .../__pycache__/game.cpython-312.pyc               | Bin 0 -> 10575 bytes
#  .../__pycache__/leaderboard.cpython-312.pyc        | Bin 0 -> 2976 bytes
#  .../__pycache__/models.cpython-312.pyc             | Bin 0 -> 14960 bytes
#  .../millionaire_client/auth.py                     |  55 ++++
#  .../millionaire_client/base.py                     | 159 +++++++++++
#  .../millionaire_client/client.py                   | 131 +++++++++
#  .../millionaire_client/competitions.py             |  61 +++++
#  .../millionaire_client/exceptions.py               |  56 ++++
#  .../millionaire_client/game.py                     | 211 +++++++++++++++
#  .../millionaire_client/leaderboard.py              |  63 +++++
#  .../millionaire_client/models.py                   | 294 +++++++++++++++++++++
#  20 files changed, 1152 insertions(+), 4 deletions(-)
#  create mode 100644 NLP_assignment_api_client/PoliMillionaire.ipynb
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__init__.py
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/auth.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/base.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/client.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/competitions.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/exceptions.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/game.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/leaderboard.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/__pycache__/models.cpython-312.pyc
#  create mode 100644 NLP_assignment_api_client/millionaire_client/auth.py
#  create mode 100644 NLP_assignment_api_client/millionaire_client/base.py
#  create mode 100644 NLP_assignment_api_client/millionaire_client/client.py
#  create mode 100644 NLP_assignment_api_client/millionaire_client/competitions.py
#  create mode 100644 NLP_assignment_api_client/millionaire_client/exceptions.py
#  create mode 100644 NLP_assignment_api_client/millionaire_client/game.py
#  create mode 100644 NLP_assignment_api_client/millionaire_client/leaderboard.py
#  create mode 100644 NLP_assignment_api_client/millionaire_client/models.py

# %%
# !ls
