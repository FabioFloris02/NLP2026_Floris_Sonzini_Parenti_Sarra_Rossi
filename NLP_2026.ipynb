# %%
# !git clone https://github.com/FabioFloris02/NLP2026_Floris_Sonzini_Parenti_Sarra_Rossi.git
# %cd NLP2026_Floris_Sonzini_Parenti_Sarra_Rossi
# Out:
# Cloning into 'NLP2026_Floris_Sonzini_Parenti_Sarra_Rossi'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), done.
# /content/NLP2026_Floris_Sonzini_Parenti_Sarra_Rossi

# %%
# !ls
# Out:
# NLP_2026.ipynb
